# %% [markdown]
# # 02 · Train with TorchDistributor
#
# 한 노트북 안에서 세 토폴로지(1×1 GPU / 1×N GPU / M×N GPU)를 섹션별로 비교한다.
# 공통 모델은 [`00-foundations/recommender-baseline.md`](../00-foundations/recommender-baseline.md).

# %% [markdown]
# ## 1×1 GPU
#
# 단일 노드 / 단일 GPU. TorchDistributor 없이 standard PyTorch loop. baseline.

# %%
# TODO: 1×1 GPU 학습 코드

# %% [markdown]
# ## 1×N GPU
#
# 단일 노드 / N GPU. `TorchDistributor(num_processes=N, local_mode=True, use_gpu=True).run(fn, ...)` + DDP.

# %%
# TODO: 1×N GPU 학습 코드

# %% [markdown]
# ## M×N GPU
#
# M 노드 / 노드당 N GPU. `TorchDistributor(num_processes=M*N, local_mode=False, use_gpu=True).run(fn, ...)` + DDP. driver→worker로 `db_host`/`db_token` 명시 전달.

# %%
# TODO: M×N GPU 학습 코드
