# %% [markdown]
# # 03 · Train with PyTorch Lightning
#
# 한 노트북 안에서 세 토폴로지(1×1 GPU / 1×N GPU / M×N GPU)를 `Trainer` 인자로만 전환한다.
# 공통 모델은 [`00-foundations/recommender-baseline.md`](../00-foundations/recommender-baseline.md).

# %% [markdown]
# ## 1×1 GPU
#
# `Trainer(accelerator='gpu', devices=1, num_nodes=1)`.

# %%
# TODO: 1×1 GPU 학습 코드

# %% [markdown]
# ## 1×N GPU
#
# `Trainer(accelerator='gpu', devices=N, num_nodes=1, strategy='ddp')`.

# %%
# TODO: 1×N GPU 학습 코드

# %% [markdown]
# ## M×N GPU
#
# `Trainer(accelerator='gpu', devices=N, num_nodes=M, strategy='ddp')`. 노드 환경변수는 TorchDistributor가 세팅.

# %%
# TODO: M×N GPU 학습 코드
