# %% [markdown]
# # 00 · Setup
#
# 실행 방식 2: 스크립트 분리. 학습 로직은 같은 디렉터리의 .py 모듈.
#
# 패키지 설치, 환경 변수, UC catalog/volume 경로, GPU 개수 등을 변수로 받아둡니다.

# %%
# TODO: %pip install ...

# %%
# TODO: CATALOG, SCHEMA, VOLUME, EXPERIMENT_PATH, RUN_NAME 등 정의
