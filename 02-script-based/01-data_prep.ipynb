# %% [markdown]
# # 01 · Data Preparation
#
# 실행 방식 2: 스크립트 분리.
#
# 데이터 준비 로직은 [`01-notebook-based/01-data_prep.ipynb`](../01-notebook-based/01-data_prep.ipynb)와 동일합니다 (MovieLens 25M → implicit feedback → UC Volume parquet shard + `_meta.json`). 이 행은 노트북 outline만 두고, 셀 내용은 후속 구현 시 01-notebook-based의 셀을 그대로 옮겨오거나 `from datasets.prep import build_ml25m`처럼 함수화해서 호출합니다.
#
# 산출 경로(`02..04-launch_*.ipynb`가 읽는 경로):
#
# ```
# {VOLUME_ROOT}/ml-25m/
#   train/shard-XXXXX.parquet
#   val/shard-XXXXX.parquet
#   _meta.json    # {"n_users": 162541, "n_items": 59047, ...}
# ```
#
# 자세한 변환 규칙·스키마는 [`00-foundations/data-loading.md`](../00-foundations/data-loading.md), 모델 config는 [`00-foundations/recommender-baseline.md`](../00-foundations/recommender-baseline.md).

# %%
# TODO: download ml-25m.zip → unzip → ratings.csv 파싱
# TODO: positive (rating>=4) + negative sampling (uniform 1:1)
# TODO: userId/movieId → dense remap, _meta.json 기록

# %%
# TODO: train/val split → /Volumes/<catalog>/<schema>/dataset/ml-25m/{train,val}/shard-*.parquet
