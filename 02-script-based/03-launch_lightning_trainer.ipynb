# %% [markdown]
# # 03 · Launch PyTorch Lightning
#
# 학습 로직은 [`lightning_trainer.py`](./lightning_trainer.py)에 있다. 본 노트북은 driver 역할로 파라미터 구성·실행·결과 확인만 담당한다.
#
# 토폴로지(1×1 / 1×N / M×N)는 launcher 인자(`num_processes`, `local_mode`, `devices`, `num_nodes`)로 전환한다.

# %%
# TODO: import 또는 %run trainer 모듈, 파라미터 정의

# %%
# TODO: launcher 호출 (TorchDistributor / Lightning Trainer / accelerate launch)

# %%
# TODO: MLflow run_id, 체크포인트 경로, 등록된 모델 출력
