# %% [markdown]
# # 01 · Data Preparation
#
# 실행 방식 3: 커스텀 패키지.
#
# 데이터 준비 로직은 [`01-notebook-based/01-data_prep.ipynb`](../01-notebook-based/01-data_prep.ipynb)와 동일합니다 (MovieLens 25M → implicit feedback → UC Volume parquet shard + `_meta.json`). 이 행에서는 `recommender_pkg`에 `prep_ml25m` 함수를 두고 노트북은 호출만 합니다.
#
# 산출 경로(`02..04-launch_*.ipynb`가 읽는 경로):
#
# ```
# {VOLUME_ROOT}/ml-25m/
#   train/shard-XXXXX.parquet
#   val/shard-XXXXX.parquet
#   _meta.json    # {"n_users": 162541, "n_items": 59047, ...}
# ```
#
# 자세한 변환 규칙·스키마는 [`00-foundations/data-loading.md`](../00-foundations/data-loading.md), 모델 config는 [`00-foundations/recommender-baseline.md`](../00-foundations/recommender-baseline.md).

# %%
# TODO: %pip install /Volumes/.../recommender_pkg-*.whl
# TODO: from recommender_pkg.data import prep_ml25m
# TODO: prep_ml25m(volume_root="/Volumes/main/distributed_cookbook/dataset")

# %%
# TODO: 산출물 확인 — _meta.json 로드, train/val shard 카운트 확인
